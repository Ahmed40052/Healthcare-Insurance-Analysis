# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the cleaned dataset
df = pd.read_csv('insurance_clean.csv')

# Compute average charges and smoker rate per region
region_summary = df.groupby('region').agg(
    avg_charges=('charges', 'mean'),
    smoker_rate=('smoker', lambda x: (x == 'yes').mean())
).round(3)

print(region_summary)
# Out:
#            avg_charges  smoker_rate
# region
# northeast    13406.385        0.207
# northwest    12450.841        0.179
# southeast    14735.411        0.250
# southwest    12346.937        0.178
